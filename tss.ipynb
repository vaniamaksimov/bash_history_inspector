# %%
from pathlib import Path


home = Path.home()
bash_history = home / '.bash_history'

# %%
with open(bash_history, 'r') as history_file:
    for line in history_file:
        print(line)
# Out:
# ls
#
# clear
#
# sudo apt update
#
# sudo apt upgrade
#
#
#
# apt list --upgradable
#
# sudo apt upgrade -y
#
# sudo apt upgrade python3-debian
#
# sudo apt upgrade gjs libgjs0g -y
#
# apt list --upgradable
#
# exit
#
# python
#
# python3
#
# exit
#
# ps aux | grep snap
#
# kill 2697
#
# sudo snap refresh snap-store
#
# exit
#
# sudo apt install gnome-terminal
#
# sudo apt remove docker-desktop
#
# rm -r $HOME/.docker/desktop
#
# sudo rm /usr/local/bin/com.docker.cli
#
# sudo apt purge docker-desktop
#
# sudo apt-get update
#
# sudo apt-get install ./docker-desktop-<version>-<arch>.deb
#
# sudo apt-get update
#
# sudo apt-get install ca-certificates curl gnupg
#
# sudo install -m 0755 -d /etc/apt/keyrings
#
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg
#
# sudo chmod a+r /etc/apt/keyrings/docker.gpg
#
# echo   "deb [arch="$(dpkg --print-architecture)" signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu \
#
#   "$(. /etc/os-release && echo "$VERSION_CODENAME")" stable" |   sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
#
# sudo apt-get install ./docker-desktop-<version>-<arch>.deb
#
# sudo apt-get install ./ docker-desktop-4.21.1-amd64.deb
#
# sudo apt-get install ./docker-desktop-4.21.1-amd64.deb
#
# l
#
# ls
#
# sudo apt-get install ./docker-desktop-4.21.1-amd64.deb
#
# sudo apt install -y ca-certificates curl gnupg lsb-release
#
# sudo mkdir -p /etc/apt/keyrings
#
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg
#
# echo "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu $(lsb_release -cs) stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
#
# sudo apt update -y
#
# sudo apt install ./docker-desktop-4.21.1-amd64.deb
#
# gpg --generate-key
#
# pass init C39AE7F751FCC47247197A2ED038D72ADD025124
#
# exit
#
# sudo apt update
#
# sudo apt upgrade -y
#
# ps
#
# ps -la
#
# sudo apt upgrade -y
#
# ps aux | grep -i apt
#
# clear
#
# sudo apt upgrade -y
#
# ps aux | grep -i apt
#
# kill 4339
#
# sudo kill 4379
#
# sudo apt upgrade -y
#
# sudo apt update
#
# apt list --upgradable
#
# sudo apt upgrade initramfs-tools-bin initramfs-tools-core initramfs-tools
#
# apt-file search bxt_dmc
#
# apt install firmware-misc-nonfree
#
# sudo apt install firmware-misc-nonfree
#
# sudo apt install firmware-linux
#
# nano
#
# nano etc/apt/sources.list
#
# cd etc
#
# ls
#
# find etc
#
# find apt
#
# find apt ~
#
# find etc/ ~
#
# find "etc/" ~
#
# clear
#
# ls
#
# cd ..
#
# ls
#
# cd ..
#
# ls
#
# cd etc/apt/
#
# ls
#
# nano sources.list
#
# sudo apt-get install linux-firmware
#
# sudo apt upgrade
#
# sudo apt update
#
# sudo apt upgrade -y
#
# clear
#
# exit
#
# sudo apt update
#
# ps
#
# ps -la
#
# exit
#
# cd Downloads/
#
# ls
#
# sudo apt install ./anydesk_6.3.0-1_amd64.deb
#
# sudo apt update
#
# sudo apt upgrade -y
#
# exit
#
# kill 6598
#
# sudo kill 6598
#
# exit
#
# apt update
#
# sudo apt update
#
# sudo apt upgrade -y
#
# sudo apt autoremove
#
# clear
#
# ls
#
# mkdir dev
#
# cd dev/
#
# ls
#
# git
#
# clear
#
# git clone git@github.com:vaniamaksimov/bash_history_inspector.git
#
# git clone https://github.com/vaniamaksimov/bash_history_inspector.git
#
# ls
#
# cd bash_history_inspector/
#
# code .
#
# code dev/bash_history_inspector/
#
# exit
#
# python3 --version
#
# clear
#
# poetry
#
# curl -sSL https://install.python-poetry.org | python3 -
#
# poetry --version
#
# poetry version
#
# clear
#
# poetry version
#
# exit
#
# code dev/bash_history_inspector/
#
# exit
#
# nano ~/.bashrc
#
# exit
#
# poetry version
#
# exit
#
# poetry version
#
# poetry config --list
#
# poetry self update
#
# poetry completions bash >> ~/.bash_completion
#
# exit
#
# poetry config virtualenvs.in-project true
#
# poetry init
#
# poetry install
#
# poetry shell
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# poetry add -G dev ruff black pytest
#
# clear
#
# mkdir .vscode
#
# touch .vscode/settings.json
#
# mkdir tests
#
# touch tests/conftest.py
#
# mkdir app
#
# touch app/__init__.py
#
# touch app/main.py
#
# kasdвов  ыыы
#
# exit
#
# nano .bash_history
#
# exit
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/main.py
#
# git commit -m 'initial commit'
#
# git config --global user.email "vaniamaksimov@gmail.com"
#
# git config --global user.name "vaniamaksimov"
#
# exit
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# ls
#
# clear
#
# exit
#
# clear
#
# poetry shell
#
# exit
#
# sudo apt update
#
# sudo apt upgrade -y
#
# hostnamectl set-hostname 'envydv7'
#
# exit
#
# git pull
#
# poetry shell
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/main.py
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/logger/__init__.py
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/main.py
#
# poetry shell
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# code dev/bash_history_inspector/
#
# exit
#
# poetry shell
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# python
#
# clear
#
# python
#
# git add .
#
# git status
#
# git push -m 'lexicon'
#
# git commit -m 'lexicon'
#
# git push
#
# sudo apt update
#
# sudo apt upgrade -y
#
# code dev/bash_history_inspector/
#
# exit
#
# source /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# pytest
#
# git commit -m 'parse log + tests'
#
# git push
#
# source /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/application.py
#
# clear
#
# poetry shel
#
# poetry shell
#
# git pull
#
# . /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# clear
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/application.py
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/history_inspector.py
#
# history
#
# clear
#
# #1699900839
#
# time if [ $(whoami|cut -c 1) == s ]; then sleep 5; fi
#
# #1699900856
#
# echo ${LS_COLORS:10:1} #;
#
# #1699900856
#
# echo ${PATH:0:1} #/
#
# #1699900871
#
# echo ${LS_COLORS:10:1} #;
#
# #1699901047
#
# exit
#
# #1699900246
#
# source /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# #1699900246
#
# /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/history_inspector.py
#
# #1699901724
#
# echo $SHELL
#
# #1699901730
#
# echo $PATH
#
# #1699901742
#
# env
#
# #1699901751
#
# export
#
# #1699901760
#
# pwd
#
# #1699901793
#
# exit
#
# #1700400405
#
# sudo apt update
#
# #1700400464
#
# sudo apt upgrade -y
#
# #1700400637
#
# clear
#
# #1700400641
#
# code dev/bash_history_inspector/
#
# #1700400644
#
# exit
#
# #1700400887
#
# python -c eval
#
# #1700400895
#
# python -c eval(
#
# #1700400898
#
# exit
#
# #1700401678
#
# source /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate
#
# #1700401687
#
# python
#
# #1700401765
#
# exit
#
# #1700403169
#
# history
#
# #1700403060
#
# history help
#
# #1700403066
#
# history --help
#
# #1700403250
#
# history -p
#
# #1700403254
#
# history
#
# #1700403445
#
# man history
#
# #1700403756
#
# exit
#
# #1700405273
#
# echo hello
#
# #1700405274
#
# exit

# %%
history
# Out:
# 'ls\nclear\nsudo apt update\nsudo apt upgrade\n\x03\napt list --upgradable\nsudo apt upgrade -y\nsudo apt upgrade python3-debian\nsudo apt upgrade gjs libgjs0g -y\napt list --upgradable\nexit\npython\npython3\nexit\nps aux | grep snap\nkill 2697\nsudo snap refresh snap-store\nexit\nsudo apt install gnome-terminal\nsudo apt remove docker-desktop\nrm -r $HOME/.docker/desktop\nsudo rm /usr/local/bin/com.docker.cli\nsudo apt purge docker-desktop\nsudo apt-get update\nsudo apt-get install ./docker-desktop-<version>-<arch>.deb\nsudo apt-get update\nsudo apt-get install ca-certificates curl gnupg\nsudo install -m 0755 -d /etc/apt/keyrings\ncurl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg\nsudo chmod a+r /etc/apt/keyrings/docker.gpg\necho   "deb [arch="$(dpkg --print-architecture)" signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu \\\n  "$(. /etc/os-release && echo "$VERSION_CODENAME")" stable" |   sudo tee /etc/apt/sources.list.d/docker.list > /dev/null\nsudo apt-get install ./docker-desktop-<version>-<arch>.deb\nsudo apt-get install ./ docker-desktop-4.21.1-amd64.deb\nsudo apt-get install ./docker-desktop-4.21.1-amd64.deb\nl\nls\nsudo apt-get install ./docker-desktop-4.21.1-amd64.deb\nsudo apt install -y ca-certificates curl gnupg lsb-release\nsudo mkdir -p /etc/apt/keyrings\ncurl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg\necho "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu $(lsb_release -cs) stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null\nsudo apt update -y\nsudo apt install ./docker-desktop-4.21.1-amd64.deb \ngpg --generate-key\npass init C39AE7F751FCC47247197A2ED038D72ADD025124\nexit\nsudo apt update\nsudo apt upgrade -y\nps\nps -la\nsudo apt upgrade -y\nps aux | grep -i apt\nclear\nsudo apt upgrade -y\nps aux | grep -i apt\nkill 4339\nsudo kill 4379\nsudo apt upgrade -y\nsudo apt update\napt list --upgradable \nsudo apt upgrade initramfs-tools-bin initramfs-tools-core initramfs-tools\napt-file search bxt_dmc\napt install firmware-misc-nonfree\nsudo apt install firmware-misc-nonfree\nsudo apt install firmware-linux\nnano\nnano etc/apt/sources.list\ncd etc\nls\nfind etc\nfind apt\nfind apt ~\nfind etc/ ~\nfind "etc/" ~\nclear\nls\ncd ..\nls\ncd ..\nls\ncd etc/apt/\nls\nnano sources.list\nsudo apt-get install linux-firmware\nsudo apt upgrade\nsudo apt update\nsudo apt upgrade -y\nclear\nexit\nsudo apt update\nps\nps -la\nexit\ncd Downloads/\nls\nsudo apt install ./anydesk_6.3.0-1_amd64.deb \nsudo apt update\nsudo apt upgrade -y\nexit\nkill 6598\nsudo kill 6598\nexit\napt update\nsudo apt update\nsudo apt upgrade -y\nsudo apt autoremove\nclear\nls\nmkdir dev\ncd dev/\nls\ngit\nclear\ngit clone git@github.com:vaniamaksimov/bash_history_inspector.git\ngit clone https://github.com/vaniamaksimov/bash_history_inspector.git\nls\ncd bash_history_inspector/\ncode .\ncode dev/bash_history_inspector/\nexit\npython3 --version\nclear\npoetry\ncurl -sSL https://install.python-poetry.org | python3 -\npoetry --version\npoetry version\nclear\npoetry version\nexit\ncode dev/bash_history_inspector/\nexit\nnano ~/.bashrc \nexit\npoetry version\nexit\npoetry version\npoetry config --list\npoetry self update\npoetry completions bash >> ~/.bash_completion\nexit\npoetry config virtualenvs.in-project true\npoetry init\npoetry install\npoetry shell\n. /home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/activate\nclear\npoetry add -G dev ruff black pytest\nclear\nmkdir .vscode\ntouch .vscode/settings.json\nmkdir tests\ntouch tests/conftest.py\nmkdir app\ntouch app/__init__.py\ntouch app/main.py\nkasdвов  ыыы\nexit\nnano .bash_history \nexit\n/home/vaniamaksimov/dev/bash_history_inspector/.venv/bin/python /home/vaniamaksimov/dev/bash_history_inspector/app/main.py\ngit commit -m \'initial commit\'\ngit config --g ...
